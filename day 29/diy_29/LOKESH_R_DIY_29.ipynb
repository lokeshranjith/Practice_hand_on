# %% [markdown]
# **Q1. Problem Statement: Hypothesis Testing** <br>
#
# Write a Python program that reads the Life Expectancy Data.csv (provided on LMS) file into a DataFrame, then drops null values and performs hypothesis testing for the given scenario.
#
# <br>
# H0:u  = average life expectancy of Afghanistan is the same as the average Life expectancy of the world (Null hypothesis)
# <br>
# H1:u = average life expectancy of Afghanistan is not the same as the average Life expectancy of the world (Alternate hypothesis)
# <br>
#
# 1.	Load dataset into a data frame
# 2.	Drop all missing values
# 3.	Take the mean of the whole target variable and extract data from ‘Afghanistan’
# 4.	consider a significance level of 0.05, perform a T-tail test using the stats library and calculate P-value and conclude hypothesis testing.

# %%
# importing required library
import pandas as pd
import numpy as np
from scipy import stats

# %%
# Reading csv file using pandas
df=pd.read_csv("Life Expectancy Data.csv")
df.head()
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling  Life expectancy
# 0                            0.479       10.1              65.0
# 1                            0.476       10.0              59.9
# 2                            0.470        9.9              59.9
# 3                            0.463        9.8              59.5
# 4                            0.454        9.5              59.2
#
# [5 rows x 22 columns]

# %%
# Finding a Null Values 
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# Life expectancy                     10
# dtype: int64

# %%
# Droping missing values
df=df.dropna()
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# Life expectancy                    0
# dtype: int64

# %%
df.head()
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afganishtan  2015  Developing            263.0             62     0.01
# 1  Afganishtan  2014  Developing            271.0             64     0.01
# 2  Afganishtan  2013  Developing            268.0             66     0.01
# 3  Afganishtan  2012  Developing            272.0             69     0.01
# 4  Afganishtan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling  Life expectancy
# 0                            0.479       10.1              65.0
# 1                            0.476       10.0              59.9
# 2                            0.470        9.9              59.9
# 3                            0.463        9.8              59.5
# 4                            0.454        9.5              59.2
#
# [5 rows x 22 columns]

# %% [markdown]
# <b>Null Hypothesis (H0):</b> average life expetancy  of the afghanistan is  same as  average Life expectancy of world<br>
# <b>Alternative Hypothesis (H1):</b> average life expetancy  of the  afghanistan is  not same as  average Life expectancy of world

# %%
# Extract the average life expectancy of world
avg_world = df["Life expectancy "].mean()
avg_world
# Out:
# 69.3023044269254

# %%
#Extract data of afghanistan
avg_afganishtan=df[df['Country'] == "Afganishtan"].sample(5,random_state=1)
avg_afganishtan
# Out:
#           Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 254   Afganishtan  2001   Developed              1.0              1    11.01
# 2850  Afganishtan  2007  Developing            157.0              0     1.01
# 2657  Afganishtan  2007  Developing            187.0              0     6.37
# 987   Afganishtan  2006  Developing            126.0              1     6.18
# 2214  Afganishtan  2001  Developing            175.0              0     3.43
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 254              2943.375396          6.0        83   58.5  ...
# 2850              342.490856          6.0         0   46.6  ...
# 2657              136.883668         89.0         0   39.3  ...
# 987               110.113829         84.0       334   49.2  ...
# 2214              199.411832         89.0         0   66.5  ...
#
#       Total expenditure  Diphtheria    HIV/AIDS           GDP  Population  \
# 254                8.29         95.0        0.1  23121.566350    128657.0
# 2850               3.67         67.0        0.1   2393.367265    219953.0
# 2657               4.82         88.0        0.7   1653.184400     13926.0
# 987                8.39         88.0        0.1   1872.684160      4136.0
# 2214               5.16         85.0        0.1   1555.474510    175566.0
#
#        thinness  1-19 years   thinness 5-9 years  \
# 254                     0.8                  0.8
# 2850                    1.6                  1.5
# 2657                    6.1                  6.5
# 987                     2.7                  2.9
# 2214                    0.2                  0.2
#
#       Income composition of resources  Schooling  Life expectancy
# 254                             0.873       18.2              78.0
# 2850                            0.579       10.7              73.0
# 2657                            0.760       12.4              69.7
# 987                             0.714       12.6              73.9
# 2214                            0.645       12.0              75.0
#
# [5 rows x 22 columns]

# %%
#ave of afganishtan
avg_afganishtan['Life expectancy '].mean()
# Out:
# 73.92

# %%
# Significance level
#significance level of 0.05,it means we are 95% confident about the hypothesis test

# %%
# determining significance level
alpha =0.05

# %% [markdown]
# <b>Statitical Test</b><br>
# We can perform the t – test as we don’t know the population standard deviation
#
# Find the critical point using Percent Point Function(PPF) or by using t-table <br>
# We need significance level and degrees of freedom to find the critical value<br>
#
# alpha = 0.05<br>
# DOF = n-1 = 5-1 = 4`

# %%
# t- distribution percent point function
from scipy.stats import t

# define probability
p=1-alpha/2
df1 =4

# %%
# retrieve value <= probability
critical_value = t.ppf(p,df1)
print("The critical value of 95% confidence level and with 4 degrees of freedom:",critical_value)
# Out:
# The critical value of 95% confidence level and with 4 degrees of freedom: 2.7764451051977987

# %%
#T-statistic value
from scipy.stats import ttest_1samp

# Calculating t-statistic and p-value
t_statistic, p_value = ttest_1samp(avg_afghanishtan["Life expectancy "], avg_world)
print('The t-statistic value is',t_statistic)
print('The p-value is',p_value)
# Out:
# The t-statistic value is 3.41967098032614
# The p-value is 0.026788268662245127
