# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ls # this function show the entire file in currently working location
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CAB5-589B
#
#  Directory of C:\Users\ADMIN\Documents\lokesh_demos_&_diy\day 25
#
# 11/06/2023  10:10 AM    <DIR>          .
# 11/06/2023  10:10 AM    <DIR>          ..
# 11/06/2023  10:06 AM    <DIR>          .ipynb_checkpoints
# 11/06/2023  10:06 AM            51,536 Demo_Normal_and_Z_Distribution.ipynb
# 11/06/2023  09:56 AM    <DIR>          DIY Solution  Day 25
# 11/06/2023  10:10 AM             8,126 practice_day_25.ipynb
# 04/29/2022  04:45 PM         1,085,084 students.csv
#                3 File(s)      1,144,746 bytes
#                4 Dir(s)  184,482,578,432 bytes free

# %%
# Reading csv file using pandas 
df=pd.read_csv("students.csv")
df.head()
# Out:
#    stud.id                 name  gender  age  height  weight    religion  \
# 1   833917  Gonzales, Christina  Female   19     160    64.8      Muslim
# 2   898539       Lozano, T'Hani  Female   19     172    73.0       Other
# 3   379678       Williams, Hanh  Female   22     168    70.6  Protestant
# 4   807564          Nem, Denzel    Male   19     183    79.7       Other
# 5   383291      Powell, Heather  Female   21     175    71.4    Catholic
#
#    nc.score semester                   major                       minor  \
# 1      1.91      1st       Political Science             Social Sciences
# 2      1.56      2nd         Social Sciences  Mathematics and Statistics
# 3      1.24      3rd         Social Sciences  Mathematics and Statistics
# 4      1.37      2nd  Environmental Sciences  Mathematics and Statistics
# 5      1.46      1st  Environmental Sciences  Mathematics and Statistics
#
#    score1  score2  online.tutorial  graduated  salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8239 entries, 1 to 8239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   stud.id          8239 non-null   int64
#  1   name             8239 non-null   object
#  2   gender           8239 non-null   object
#  3   age              8239 non-null   int64
#  4   height           8239 non-null   int64
#  5   weight           8239 non-null   float64
#  6   religion         8239 non-null   object
#  7   nc.score         8239 non-null   float64
#  8   semester         8239 non-null   object
#  9   major            8239 non-null   object
#  10  minor            8239 non-null   object
#  11  score1           4892 non-null   float64
#  12  score2           4892 non-null   float64
#  13  online.tutorial  8239 non-null   int64
#  14  graduated        8239 non-null   int64
#  15  salary           1753 non-null   float64
# dtypes: float64(5), int64(5), object(6)
# ...

# %%
df.columns
# Out:
# Index(['stud.id', 'name', 'gender', 'age', 'height', 'weight', 'religion',
#        'nc.score', 'semester', 'major', 'minor', 'score1', 'score2',
#        'online.tutorial', 'graduated', 'salary'],
#       dtype='object')

# %%
# shape of the data
print("Number of Rows :",df.shape[0])
print("Number of Columns :",df.shape[1])
# Out:
# Number of Rows : 8239
# Number of Columns : 16

# %% [markdown]
# ## Normal Distribution
# It is a symmetric distribution where most of the observations lies around the mean. The distribution looks like a bell curve.<br>
# Normal distribution is frequently seen in real world. For example, data related to height, age, income and many more

# %% [markdown]
# Consider weight data of students from the dataset, find its distribution along with its mean and standard deviation, and also find its skewness and kurtosis

# %%
weights=df.weight
weights.head(10)
# Out:
# 1     64.8
# 2     73.0
# 3     70.6
# 4     79.7
# 5     71.4
# 6     85.8
# 7     65.9
# 8     65.7
# 9     94.4
# 10    66.0
# Name: weight, dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# plotting the distribution
sns.distplot(weights,hist=False)
# Out:
# <Axes: xlabel='weight', ylabel='Density'>

# %%
# Calculating the mean and std for normal distribution
print("Mean:",weights.mean())
print("Standard Deviation:",weights.std())
# Out:
# Mean: 72.99813084112151
# Standard Deviation: 8.635161688392094

# %%
# Finding the skewness and kurtosis

from scipy import stats
skew=stats.skew(weights)
print("Skewness:",skew)
kurt=stats.kurtosis(weights)
print("Kurtosis:",kurt)
# Out:
# Skewness: 0.6508854364719628
# Kurtosis: 0.2921368367627899

# %% [markdown]
# Both Skewness and Kurtosis are approximately equal to zero

# %% [markdown]
# ## Z - Distribution (Standard Normal Distribution)
# Standard normal distribution is a special case of normal distribution where mean is 0 and standard deviation is 1<br>
#
# We can convert a Normal Distribution into Z - Distribution by finding the z - scores of data points of normally distributed
# data

# %% [markdown]
# ### Z-score
# Convert the weight data of students into Z - Distribution by calculating its z-scores and find its mean and stanrdard deviation¶

# %%
# Calculate z-score
from scipy import stats

z_score=stats.zscore(weights,axis=0)
z_score
# Out:
# 1      -0.949447
# 2       0.000216
# 3      -0.277734
# 4       0.776161
# 5      -0.185084
#           ...
# 8235    0.706673
# 8236   -0.046109
# 8237   -0.613590
# 8238    2.965020
# 8239   -0.463034
# Name: weight, Length: 8239, dtype: float64

# %%
# Plotting the distribution of the data
sns.distplot(z_score,hist=False)
# Out:
# <Axes: xlabel='weight', ylabel='Density'>

# %% [markdown]
# The above distribution is a Standard Normal Distribution as the data values are standardized by converting into z-scores

# %% [markdown]
# #### The Mean and the Standard Deviation of a standard normal distribution is equal to 0 and 1 respectively

# %%
# Calculatin the mean and standard deviation of the standard normal distribution
print("Mean of z_score",z_score.mean())
print("\nStandard deviation of z_score",z_score.std())
# Out:
# Mean of z_score -1.5062057142918012e-15
#
# Standard deviation of z_score 1.0000606925014972

# %% [markdown]
# The mean and the standard deviation of standard normal distribution is approximately equal to 0 and 1 respectively

# %% [markdown]
# ### Weight of the student is 60, find out the how many standard deviation away the point is located from mean where mean is 72.9 and standard deviation is 8.63 as per the weights data of students
#
# Given weight is 60<br>
# Let us consider the weight data and find its z-score

# %%
z_score=(60-72.9)/8.63
z_score
# Out:
# -1.494785631517961

# %% [markdown]
# # diy 25

# %% [markdown]
# **Q1. Problem Statement: Probability Distribution** <br>
# Load the exam.csv dataset into a DataFrame and perform the following tasks on “math score,” ”reading score,” and “writing score” columns:
# 1. Plot the distributions using the seaborn library
# 2. Find the mean and standard deviation using the scipy library
# 3. Find skewness and kurtosis using the stats module from the scipy library
# 4. Find Standard Normal Distribution (z-score) using the stats module from the scipy
# library
# 5. Plot the Z distribution using the seaborn library

# %%
data=pd.read_csv(r"C:\Users\ADMIN\Documents\lokesh_demos_&_diy\day 25\DIY Solution  Day 25\exam.csv")
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group B                 high school  free/reduced
# 1    male        group A          associate's degree      standard
# 2    male        group C            some high school  free/reduced
# 3  female        group D            some high school      standard
# 4  female        group A           bachelor's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          53             50             46
# 1                    none          73             73             68
# 2               completed          45             43             41
# 3               completed          80             73             76
# 4                    none          74             95             92

# %% [markdown]
# Plot the distributions using the seaborn library

# %%
fig,ax=plt.subplots(1,3, figsize=(15,5))
sns.distplot(ax=ax[0],x=data['math score'],hist=False)
sns.distplot(ax=ax[1],x=data['writing score'],hist=False)
sns.distplot(ax=ax[2],x=data['reading score'],hist=False)
ax[0].set(xlabel='math score')
ax[1].set(xlabel='writing score')
ax[2].set(xlabel='reading score')
plt.show()

# %%
import scipy
print("Mean:",scipy.mean(data['math score']))
      
print("std",scipy.std(data['math score']))
# Out:
# Mean: 67.095
# std 14.674875638314619

# %%
cols=['math score','writing score','reading score']
for i in cols:
    print("\n")
    print("Mean",i,":",data[i].mean())
    print("Standard deviation",i,":",data[i].std())
# Out:
# Mean math score : 67.095
# Standard deviation math score : 14.682218583802056
#
#
# Mean writing score : 68.85
# Standard deviation writing score : 14.465156091129483
#
#
# Mean reading score : 70.189
# Standard deviation reading score : 13.816807995451876

# %%
from scipy import stats
for i in cols:
    #finding skewness
    print("\n")
    print("The skewness of the",i,":",stats.skew(data[i]))
    #finding kurtosis
    print("The kurtosis of the",i,":",stats.kurtosis(data[i]))
# Out:
# The skewness of the math score : -0.2473493688814472
# The kurtosis of the math score : 0.0344647614728113
#
#
# The skewness of the writing score : -0.1920097699458864
# The kurtosis of the writing score : -0.00877069922851037
#
#
# The skewness of the reading score : -0.19513845535327878
# The kurtosis of the reading score : -0.10424341727490205

# %%
for i in cols:
    z_score=stats.zscore(data[i],axis=0)
    print("\n")
    print("z_score of",i,":",z_score)
# Out:
# z_score of math score : 0     -0.960485
# 1      0.402388
# 2     -1.505635
# 3      0.879394
# 4      0.470532
#          ...
# 995   -1.233060
# 996    0.743107
# 997   -2.050784
# 998   -0.960485
# 999    1.424544
# Name: math score, Length: 1000, dtype: float64
#
#
# z_score of writing score : 0     -1.580448
# 1     -0.058791
# 2     -1.926280
# 3      0.494539
# 4      1.601198
#          ...
# 995   -0.957952
# 996    0.771204
# 997   -1.096285
# 998   -0.612121
# 999    2.154528
# Name: writing score, Length: 1000, dtype: float64
#
#
# z_score of reading score : 0     -1.461922
# 1      0.203550
# 2     -1.968805
# 3      0.203550
# 4      1.796610
#          ...
# 995   -1.751570
# 996    0.565609
# 997   -1.172275
# 998   -1.099863
# 999    2.158669
# Name: reading score, Length: 1000, dtype: float64

# %%
fig, ax = plt.subplots(1,3, figsize = [20,5])
sns.distplot(ax=ax[0],x=stats.zscore(data['math score']),hist=False)
sns.distplot(ax=ax[1],x=stats.zscore(data['writing score']),hist=False)
sns.distplot(ax=ax[2],x=stats.zscore(data['reading score']),hist=False)
ax[0].set(xlabel='math score')
ax[1].set(xlabel='writing score')
ax[2].set(xlabel='reading score')
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize = [20,5]) # Rows, Columns | figsize: Width, Height
for i, j in zip(cols, ax.flatten()):
    print(i)
    print(j)
    platting=sns.distplot(stats.zscore(data[i],axis=0),ax=j,hist=False)
# Out:
# math score
# Axes(0.125,0.11;0.227941x0.77)
# writing score
# Axes(0.398529,0.11;0.227941x0.77)
# reading score
# Axes(0.672059,0.11;0.227941x0.77)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
for i in cols:
    z_score=ss.fit_transform(data[i].values.reshape(-1,1))
    print("Z_Score of ",i,":\n",z_score)
# Out:
# Z_Score of  math score :
#  [[-0.96048514]
#  [ 0.40238842]
#  [-1.50563457]
#  [ 0.87939416]
#  [ 0.4705321 ]
#  [ 0.94753784]
#  [ 1.01568152]
#  [ 0.19795738]
#  [-1.77820928]
#  [-0.55162307]
#  [-2.66407709]
#  [ 0.26610106]
#  [-0.34719204]
#  [-0.61976675]
#  [ 0.33424474]
#  [ 1.0838252 ]
#  [-0.00647365]
#  [-0.41533572]
#  [ 0.53867577]
#  [-0.14276101]
#  [ 0.87939416]
#  [ 1.0838252 ]
#  [-0.14276101]
#  [-0.00647365]
#  [-0.34719204]
#  [ 1.90154933]
#  [ 2.17412405]
#  [ 1.96969301]
#  [-1.23305985]
#  [-0.07461733]
#  [-1.57377824]
#  [-1.23305985]
#  [-0.14276101]
#  [-0.75605411]
#  [ 0.67496313]
#  [ 0.40238842]
#  [ 1.0838252 ]
#  [-0.82419779]
#  [-3.89066329]
#  [-0.41533572]
#  [ 1.22011255]
#  [-0.4834794 ]
#  [-1.36934721]
#  [-0.21090468]
#  [ 0.67496313]
#  [ 1.96969301]
#  [ 0.67496313]
#  [ 1.0838252 ]
#  [ 0.26610106]
#  [-0.00647365]
#  [-0.68791043]
#  [ 1.49268727]
#  [-0.07461733]
#  [ 0.67496313]
#  [ 1.28825623]
#  [-0.14276101]
#  [-0.00647365]
# ...
