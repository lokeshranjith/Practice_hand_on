# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading a dataset

# %%
car=pd.read_csv("Car_sales.csv")
car.head()
# Out:
#     Manufacturer              Model  Sales in thousands  4-year resale value  \
# 0     Mitsubishi  3000GT                          0.110            20.940000
# 1          Dodge  Viper                           0.916            58.470000
# 2  Mercedes-Benz  CL500                           0.954            18.072975
# 3     Oldsmobile  Cutlass                         1.112            11.240000
# 4        Porsche  Carrera Coupe                   1.280            60.625000
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger              25.450          3.0       161.0       97.2   72.4
# 1    Passenger              69.725          8.0       450.0       96.2   75.7
# 2    Passenger              85.500          5.0       302.0      113.6   73.1
# 3    Passenger              18.145          3.1       150.0      107.0   69.4
# 4    Passenger              71.020          3.4       300.0       92.6   69.5
#
# ...

# %% [markdown]
# ## Line plot

# %%
# Sorting dataset by "Sales in thousands"
car=car.sort_values("Sales in thousands")
#Plotting simple live plot to see there trends of "Sales in thousands"
plt.plot(car["Sales in thousands"],label="Sales in thousands")
plt.legend()
plt.show()

# %% [markdown]
# #### Here, We can say that "sales in thousands" slowly increase from 0-120 spikes exactly high

# %% [markdown]
# ## Bar plot

# %%
# Mean 4-years resale value for each Manufacturer
plt.figure(figsize=(10,8))
for group,data in car. groupby("Manufacturer"):
    plt.barh(group,data["4-year resale value"].mean())

# %%
# Plotting Vehicle type Manufacturer make
vt_dict=dict()
for i in set(car['Vehicle type']):
    vt_dict[i]=car[car['Vehicle type']==i].Manufacturer.count()
plt.bar(vt_dict.keys(),vt_dict.values())
plt.show()

# %% [markdown]
# #### We can see that Manufacturers manufacture more number of "Passenger" types of case

# %% [markdown]
# ## stacked bar plot

# %%
# Mean 4-year resale value and prise in thousands for each Manufaturer
plt.figure(figsize=(10,8))
for group,data in car.groupby ("Manufacturer"):
    plt.barh(group,data["4-year resale value"].mean())
    plt.barh(group,data['Price in thousands'].mean(),left=data["4-year resale value"].mean())

# %% [markdown]
# ## Histogram

# %%
car.Horsepower=car.Horsepower.fillna(car.Horsepower.mean())
plt.hist(car.Horsepower,bins=10)
plt.show()

# %% [markdown]
# #### From the above histogram we can say that most of the cars has horsepower between 100-120

# %% [markdown]
# ## Pie chart

# %%
m_dict=dict()
plt.figure(figsize=(10,8))
for manufacturer in set(car.Manufacturer):
    m_dict[manufacturer]=car[car.Manufacturer==manufacturer].Manufacturer.count()
plt.pie(m_dict.values(),labels=m_dict.keys())
plt.show()

# %% [markdown]
# #### Herw, The pie chart shows that "Ford" and "Dodge" launched more number of moduls while "Jaguar" and "infiniti" launched very less

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(car["Fuel capacity"],car["Fuel efficiency"])
plt.show()

# %% [markdown]
# #### Here, From the above scatter pot we can see that as "Fuel capacity" increases the "Fuel efficiency" gradually decreases

# %% [markdown]
# ## Box plot

# %%
car["Curb weight"].isna().any()#Checking for any null values in boxplot
car=car['Curb weight'].fillna(car['Curb weight'].mean())
plt.boxplot(car)
plt.show()

# %%
x=np.arange(5)
plt.plot(x,x,label="even",marker="D")
plt.plot(x,x*x,label="Squar",marker="*")
plt.plot(x,x*x*x,label='Cube',marker="^")
plt.legend()
plt.show()

# %%
arr={'name':["100% Bran","100% Natural Bran","All-Bran","All-Bran with Extra Fiber","Almond Delight","Apple Cinnamon Cheerios",
            "Apple Jacks","Basic 4","Bran Chex",'Bran Flakes'],'calories':[70,120,70,50,110,110,110,130,90,90],
    "Sodium":[130,15,260,140,200,180,125,210,200,210],"Potass":[280,135,320,330,-1,70,30,100,125,190],
     "Rating":[69.40,33.98,59.42,93.70,34.38,29.50,33.17,37.03,49.12,53.31]}

# %%
df=pd.DataFrame(arr)
df.head()
# Out:
#                         name  calories  Sodium  Potass  Rating
# 0                  100% Bran        70     130     280   69.40
# 1          100% Natural Bran       120      15     135   33.98
# 2                   All-Bran        70     260     320   59.42
# 3  All-Bran with Extra Fiber        50     140     330   93.70
# 4             Almond Delight       110     200      -1   34.38

# %%
#Subplots
index=1
plt.figure(figsize=(8,8))
for col in df.column[1:]:
    plt.subplot(2,2,index)
    plt.plot(df[col])
    plt.title("Col")
    index+=1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 4
#       2 index=1
#       3 plt.figure(figsize=(8,8))
# ----> 4 for col in df.column[1:]:
#       5     plt.subplot(2,2,index)
#       6     plt.plot(df[col])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'
